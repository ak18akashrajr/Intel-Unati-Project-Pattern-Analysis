# %%
#importing all required modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read dataset 
df=pd.read_csv("unnati_phase1_data_revised.csv")
df
# Out:
#          Alert        Date   Time        Lat       Long  Vehicle  Speed
# 0      cas_ldw  01-06-2022  05:36  12.887403  80.083412     2846     48
# 1      cas_ldw  01-06-2022  05:36  12.892586  80.085794     2846     58
# 2      cas_ldw  01-06-2022  05:37  12.894932  80.087564     2846     57
# 3      cas_ldw  01-06-2022  05:37  12.898267  80.090062     2846     49
# 4      cas_ldw  01-06-2022  05:38  12.901594  80.092538     2846     58
# ...        ...         ...    ...        ...        ...      ...    ...
# 21320  cas_pcw  31-08-2022  18:12  13.070668  80.265539     5339     30
# 21321  cas_pcw  31-08-2022  18:13  13.071554  80.264616     5339     34
# 21322  cas_hmw  31-08-2022  18:15  13.071181  80.258729     5339     24
# 21323  cas_pcw  31-08-2022  18:16  13.067723  80.255065     5339     23
# 21324  cas_hmw  31-08-2022  18:19  13.065917  80.247777     5339     22
#
# [21325 rows x 7 columns]

# %% [markdown]
# legend of dataset as follows
# cas_fcw-> Forward Collision Warning
# cas_pcw-> Pedestrian Collision Warning
# cas_ldw-> Lane Departure Warning
# cas_hmw-> Headway Monitoring and Warning

# %%
a=df.shape
a
# Out:
# (21325, 7)

# %%
df.columns
# Out:
# Index(['Alert', 'Date', 'Time', 'Lat', 'Long', 'Vehicle', 'Speed'], dtype='object')

# %%
df=df.drop(['Date'],axis=1)
df.head()
# Out:
#      Alert   Time        Lat       Long  Vehicle  Speed
# 0  cas_ldw  05:36  12.887403  80.083412     2846     48
# 1  cas_ldw  05:36  12.892586  80.085794     2846     58
# 2  cas_ldw  05:37  12.894932  80.087564     2846     57
# 3  cas_ldw  05:37  12.898267  80.090062     2846     49
# 4  cas_ldw  05:38  12.901594  80.092538     2846     58

# %%
df.columns
# Out:
# Index(['Alert', 'Time', 'Lat', 'Long', 'Vehicle', 'Speed'], dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of          Alert   Time        Lat       Long  Vehicle  Speed
# 0      cas_ldw  05:36  12.887403  80.083412     2846     48
# 1      cas_ldw  05:36  12.892586  80.085794     2846     58
# 2      cas_ldw  05:37  12.894932  80.087564     2846     57
# 3      cas_ldw  05:37  12.898267  80.090062     2846     49
# 4      cas_ldw  05:38  12.901594  80.092538     2846     58
# ...        ...    ...        ...        ...      ...    ...
# 21320  cas_pcw  18:12  13.070668  80.265539     5339     30
# 21321  cas_pcw  18:13  13.071554  80.264616     5339     34
# 21322  cas_hmw  18:15  13.071181  80.258729     5339     24
# 21323  cas_pcw  18:16  13.067723  80.255065     5339     23
# 21324  cas_hmw  18:19  13.065917  80.247777     5339     22
#
# [21325 rows x 6 columns]>

# %%
#dropping duplicates
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (18645, 6)

# %%
sns.countplot(x="Alert",data=df,palette="bwr")
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x="Vehicle",data=df,palette="bwr")
plt.xticks(rotation=90)
plt.show()

# %%
sns.stripplot(x="Lat",data=df,hue="Long")
# ax = sns.stripplot(x);
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# From the above we can infer that the most of accidents occured by the Headway Monitoring and Warning and it's caused by the vehicle category of 805 with the co-ordinates (13.1,80.3) -> @ Chennai -> Royapuram
# (Post Signal Station, Chennai Port Entry Road, Zone 5 Royapuram, Chennai - 600001, Tamil Nadu, India)
# Thus the Royapuram Area needs to be monitored in order to reduce the accidents.
